# %% [markdown]
# # 一、梯度下降算法的背景知识

# %% [markdown]
# 梯度下降是迭代法的一种,可以用于求解最小二乘问题(线性和非线性都可以)。
# 在求解机器学习算法的模型参数，即无约束优化问题时，梯度下降是最常采用的方法之一，另一种常用的方法是最小二乘法。
#
# 梯度下降法是一种通过重复步骤使机器学习模型收敛到最小值的优化算法。
# 从本质上讲，梯度下降法是通过求出函数输出最小的值来最小化函数的。
# 这个函数通常是一个损失函数。
#
# 损失函数衡量的是我们的模型与实际情况相比的糟糕程度。
# 因此，我们只有减少这种损失才有意义。

# %% [markdown]
# #### 一个简单的梯度下降算法如下:
#  - 获得使F(x)最小化的函数
#  - 初始化一个值x，从该值开始下降就进行优化
#  - 指定一个学习率，该学习率将确定要下降多少步，或收敛到最小值的速度有多快
#  - 得到x的导数(下降)
#  - 继续下降，这个值的导数乘以学习速率
#  - 不断更新x的值
#  - 检查您的停止状态，看是否要停止
#  - 如果条件满足，停止。如果没有，则使用新的x值继续第4步，并保持重复算法

# %% [markdown]
# # 二、编程求9的4次方根

# %% [markdown]
# ### 1) 探索不同a取值对结果的影响，画出不同的a下的学习过程，即 cost function 随迭代次数的变化

# %%
import matplotlib.pyplot as plt 
import numpy as np
from scipy import stats
# %matplotlib inline
import math
def L(x):
    Lx=0.5*(x**4.0-9.0)**2.0   
    return Lx
def f(t):   
    ft=4*(pow(t,4)-9)*x**3    
    return ft
p=1.7321   #9的4次方根近似值

# %%
a=0.000002     
x=1             
iterations=[]
cost_function=[]
i=1
value=0
while abs(x-p)>0.0001 :
    x=x-a*f(x)
    i=i+1
    iterations.append(i)        
    value=L(x)
    cost_function.append(value)        
plt.plot(iterations,cost_function)
plt.title('$cost_function-iterations$')
plt.xlabel("$iterations$")
plt.ylabel("$cost_function$")
# Out:
# Text(0, 0.5, '$cost_function$')

# %%
a=0.000005          
x=1
iterations=[]
cost_function=[]
i=1
value=0
while abs(x-p)>0.0001 :
    x=x-a*f(x)
    i=i+1
    iterations.append(i)      
    value=L(x)
    cost_function.append(value)        
plt.plot(iterations,cost_function)   
plt.title('$cost_function-iterations$')
plt.xlabel("$iterations$")
plt.ylabel("$cost_function$")
# Out:
# Text(0, 0.5, '$cost_function$')

# %%
a=0.00008
x=1
iterations=[]
cost_function=[]
i=1
value=0
while abs(x-p)>0.0001 :
    x=x-a*f(x)
    i=i+1
    iterations.append(i)       
    value=L(x)
    cost_function.append(value)        
plt.plot(iterations,cost_function)   
plt.title('$cost_function-iterations$')
plt.xlabel("$iterations$")
plt.ylabel("$cost_function$")
# Out:
# Text(0, 0.5, '$cost_function$')

# %%
a=0.001
x=1
iterations=[]
cost_function=[]
i=1
value=0
while abs(x-p)>0.0001 :
    x=x-a*f(x)
    i=i+1
    iterations.append(i)       
    value=L(x)
    cost_function.append(value)        
plt.plot(iterations,cost_function)   
plt.title('$cost_function-iterations$')
plt.xlabel("$iterations$")
plt.ylabel("$cost_function$")
# Out:
# Text(0, 0.5, '$cost_function$')

# %%
a=0.0045       
x=1
iterations=[]
cost_function=[]
i=1
value=0
while abs(x-p)>0.0001 :
    x=x-a*f(x)
    i=i+1
    iterations.append(i)      
    value=L(x)
    cost_function.append(value)        
plt.plot(iterations,cost_function)   
plt.title('$cost_function-iterations$')
plt.xlabel("$iterations$")
plt.ylabel("$cost_function$")
# Out:
# Text(0, 0.5, '$cost_function$')

# %%
a=0.0065      #继续增大学习率，出现震荡现象
x=1
iterations=[]
cost_function=[]
i=1
value=0
while abs(x-p)>0.001 :
    x=x-a*f(x)
    i=i+1
    iterations.append(i)        
    value=L(x)
    cost_function.append(value)        
plt.plot(iterations,cost_function)   
plt.title('$cost_function-iterations$')
plt.xlabel("$iterations$")
plt.ylabel("$cost_function$")
# Out:
# Text(0, 0.5, '$cost_function$')

# %%
a=0.008       #继续增大学习率，震荡更加明显
x=1
iterations=[]
cost_function=[]
i=1
value=0
while abs(x-p)>0.001 :
    x=x-a*f(x)
    i=i+1
    iterations.append(i)        
    value=L(x)
    cost_function.append(value)       
plt.plot(iterations,cost_function)   
plt.title('$cost_function-iterations$')
plt.xlabel("$iterations$")
plt.ylabel("$cost_function$")
# Out:
# Text(0, 0.5, '$cost_function$')

# %%
a=4           #学习率过大得到错误结果
x=1
iterations=[] 
cost_function=[]
i=1
value=0
while abs(x-p)>0.1 :       
    x=x-a*f(x)
    i=i+1
    iterations.append(i)    
    value=L(x)
    cost_function.append(value)     
plt.plot(iterations,cost_function)   
plt.title('$cost_function-iterations$')
plt.xlabel("$iterations$")
plt.ylabel("$cost_function$")
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-9-d59c3cb68339> in <module>
#       9     i=i+1
#      10     iterations.append(i)
# ---> 11     value=L(x)
#      12     cost_function.append(value)
#      13 plt.plot(iterations,cost_function)
#
# <ipython-input-8-60fdd2adfba4> in L(x)
#       5 import math
#       6 def L(x):
# ----> 7     Lx=0.5*(x**4.0-9.0)**2.0
#       8     return Lx
#       9 def f(t):
#
# OverflowError: (34, 'Result too large')

# %% [markdown]
# ##### 结论：
# 上面几个例子分别展示了学习率a在逐渐增大的过程中，损失函数的变化情况。
#
# 可以看出，刚开始随着a增大，误差函数越来越快地趋于0，但当a过大时，
# 损失函数将出现振荡现象，难以得到平稳的值。此时a越大震荡越明显，甚至最后无法得到正确的结果。

# %% [markdown]
# ### 2) 寻找合适的a

# %%
iterations=[]
alpha=[]
for j in range(38,42,1):     #学习率a从0.00005变化到0.00455，每次增加0.000005
    a=0.1*j
    x=1   
    n=0
    while  abs(x-p)>0.1:
        x=x-a*f(x)
        n=n+1
    iterations.append(n)       
    alpha.append(a)       
plt.plot(alpha,iterations)
plt.title('$cost_function-iterations$')
plt.xlabel(r'$\alpha$')
plt.ylabel("$iterations$")
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-3-c61a8caa0331> in <module>
#       6     n=0
#       7     while  abs(x-p)>0.1:
# ----> 8         x=x-a*f(x)
#       9         n=n+1
#      10     iterations.append(n)
#
# <ipython-input-1-c65a0f60efbf> in f(t)
#       8     return Lx
#       9 def f(t):
# ---> 10     ft=4*(pow(t,4)-9)*x**3
#      11     return ft
#      12 p=1.7321   #9的4次方根近似值
#
# OverflowError: (34, 'Result too large')

# %% [markdown]
# #### 结论：
# 从上图可见，总体来看在一定范围内，学习率增加，学习过程能更快地到达稳定状态。
#
# 而在经历了一个“最佳”的学习率区间后，我们可以看到迭代次数随着学习率增加而增加。
#
# 随着学习率继续变大，由之前所做的图会发现出现震荡，数据失去意义。

# %% [markdown]
# # 三、对图形的解释

# %% [markdown]
# 从上面的讨论看出，题中所给的学习过程，推断原因在于学习率取得过大，
# 导致产生了震荡现象。
